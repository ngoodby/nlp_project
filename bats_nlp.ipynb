# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('bat_tweets_final.csv')

# %%
df.shape
# Out:
# (19443, 37)

# %%
df.date.min()
# Out:
# '2018-12-31'

# %%
df.date.max()
# Out:
# '2022-06-09'

# %%
df['created_at'] = pd.to_datetime(df.created_at)

# %%
#create variable to indicate whether tweet came before or after 2020
df['covid'] = np.where(df.created_at < "2019-12-31", "pre", "post")

# %%
#initial cleaning
import re
import string
def clean_tweet(tweet):
    if type(tweet) == float:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) # to avoid removing contractions
    temp = re.sub("@[A-Za-z0-9_]+","", temp) # remove mentions
    temp = re.sub("#[A-Za-z0-9_]+","", temp) # remove hashtags
    temp = re.sub(r'http\S+', '', temp) # remove urls
    temp = re.sub('[%s]' % re.escape(string.punctuation), '', temp) #remove puncuation
    temp = re.sub("[^a-z0-9]"," ", temp) #filter non-alphanumeric characters
    return temp
results = [clean_tweet(tw) for tw in df.tweet]
results
# Out:
# ['vortex wind power is wildlifefriendly and safe for birds bats bees sugar amp squirrel gliders but bladed wind turbines kill millions of native wildlife species annually  110   330 birds amp 200   670 bats per wind turbine are mutilated and die lt ',
#  '       but i think you have ignored my point about the damage intensive agriculture does in the first place the wildlife that could be there isn t autumn hacking of hedges so no food or cover spraying removing insects so no bats trees gone lincs farms are not full of biodiversity',
#  ' not sure why  characterises protected species such as bats as pests  ditto bees etc  reinforcing negative stereotypes of our valuable wildlife someone needs to rewrite this page  ',
#  '  nah the native stuff is all pretty friendly the only native mammal is a tiny ickle bat the only venomous spider is so rare its an endangered species australian wildlife now that is terrifying',
#  'read this about bats         ',
#  'any ideas what this might be  looks like some kind of camera  maybe for wildlife or traffic    on a pole on beaudesertnerang road near the trees where the bats are  doesnt look department of traffic and roads issued or installed',
#  'jolyon maugham qc was a hero to many then he beat a fox to death   my boxing day would have been better if id heard this scumbag had had the receiving end of an encounter with a baseball bat of the very nastiest kind ',
#  'need ideas for a diy project between christmas and new year  if you have a garden why not treat your local wildlife feed birds and create a home for animals and insects such as bat and bird boxes bug hotels or log piles   ',
#  'its a bloody disgrace we need to know what a wind turbine actually costs to build life of one waste when finished wild life killed ie habitat birds bats',
#  ' kia ora russell if youd like to share this fb link with your followers id be grateful its the hunter wildlife rescue natf inc who are taking care of orphaned bats they dont receive govt funding cheers mate   ',
#  'is he kidding   perform your values        it was clear he had been waiting for the chance thats premeditated mlud   the values he performed  the trapping injury and killing of wildlife with a baseball bat  while wearing a kimono  ',
#  'i dunno what im going to do for 3 hours while this cooks  but im pretty sure it involves a kimono a baseball bat and some innocent wildlife  ',
#  '        i volunteer as an animalcaretaker in rescuecenters for wildlife there are bats foxes  i am vaccinated for rabies simple and easy',
#  '  i want to make sure that in my mentioning wind turbines kill birds amp bats that it isnt misconstrued that we should still use old methods i dont i read a tweet saying that they dont kill wildlife when they do just letting mr takei know this in case he didnt',
#  '       there was a case of a man in 2002 who died from rabies contracted from a bat bite he volunteered as a conservationist for snh and monitored his local bat population in angus tragic but true no reason not to be kind to wildlife but be aware of it if you do suffer a bite',
#  ' what a horrible being you are to not only act like that but to appear to boast about it too is this always your solution to life a baseball bat you should be ashamed regrettably for every person that sticks up for wildlifetheres  a slaughterer like youshameful',
#  'going to have a word with that jolyon fella about his behaviour towards wildlife  hopefully hell be in the snug at the fox and bat this evening',
#  '      i see arguments on both sides an independent article states the line  will also cut through at least 61 areas of woodland many of which are centuries old and home to rare species of birds and bats where will wildlife go waiting for replacement trees to mature',
#  ' you will be classed as a murderer killing wildlife with a bat and you are a qc shame on you firstly you could have called the rspca they could have dealt with it but not with a bat  i think you are a snob killer how you can sleep at night god knows',
#  '   there are laws against killing wildlife in a cruel manner which i believe would include killing a fox with a bat',
#  '   us fish and wildlife service is offering up to 100000 in awards to solvers for innovative ways to permanently eradicate weaken or disarm the fungus that causes whitenose syndrome in north american bats find out more here     ',
#  ' do you beat your wildlife with a baseball bat like an uncouth transatlantic johnny or do you drive it with a straight honest english cricket bat to ensure fair play and more to the point do you wear lady wrassles dressing gown nightie hairnet amp fluffy slippers for the task',
#  '  no it was trapped that poor fox was frightened and would have felt pain when he smacked it with the baseball bat no matter how you feel about wildlife the fox did not deserve to be killed especially in that manner also why are you saying alleged',
#  'got 2 handmade bird boxes and a handmade bat box for christmas  yay     ',
#  '    i was told there was a tweet before about getting a baseball bat because one of his hens was missing and blaming the fox so this was not totally unexpected but also was the netting hazardous to wildlife neighbouring cats',
#  ' it got caught in his fence the chickens weren t in immediate danger even if they were beating it to death with a baseball bat wasn t the nicest option he should have called the proper authorities rspca aren t the only wildlife responders in london agree context is key',
#  'i m all for being nice amp getting along with as many people as i can in life  that said if you re into killing wildlife with guns baseball bats or packs of dogs then you re  a weak human being amp an absolute dickhead  i wish everyoneexcept youa great day  ',
#  '  over 60 million acres are under superweeds now all insect numbers are plummeting bees butterflies pollinators birds bats wildlife snails worms even the soil is dying  you think human allergies are like pesticide resistance   no mate i wont be seeking your advice',
#  '  wildlife especially unlucky if the owner of said coop keeps a baseball bat for no discernible reason other than as a weapon',
#  '    whenever i dont know what to do i dont batter the local wildlife to death with a baseball bat  i pause reflect then take appropriate action in this case i would have called the rspca',
#  'bats are a vital part of our native wildlife and are excellent indicators for the wider health of the uks wildlife    ',
#  '   make your mind up it was either trapped or not trapped so either capable of getting the hens or not youre still an arsehole for battering wildlife with a baseball bat just your presence alone would have scared it away sub human scum',
#  '           please take a look at the comment from traffic   countries pull out of wildlife accord aimed at saving iconic animals  ',
#  '  1 he has stated that the fox was trapped in netting and was therefore no threat to anyone or anything except itself a wildlife rescue would have been happy to attend and help 2 evidently baseball bat is his preferred method of dealing with any wildlife  ',
#  '  unfortunately none of that applies according to his own tweets  also any number of wildlife and fox rescue services were available if he d bothered to phone and its not the first time he s gone out with a baseball bat with the intent of dispatching a fox',
#  ' na this is a toffee nosed city twat that thinks hes being countrified by keeping chickens which he has no idea how to keep or protect resulting in wildlife being trapped in his netting him killing it with a baseball bat imo is a sign of someone who s mental',
#  '   if he could get close enough with a baseball bat it couldn t have been a danger to him should have called a wildlife organisation absolutely no excuse for doing that to an animal',
#  ' so he killed s fox with a bat no different from stunning them with a gun or electrodes  people who live in town have no idea about containing wildlife and that packham clot aught to know better',
#  ' you mean beat a trapped amp terrified animal to death with a baseball bat rather than ring  or the fox project or any of the other wildlife orgs that could help then tried to justify it as an act of mercy',
#  ' so i get shocked and spooked by an intruder in my garden who looks intimidating  does that mean i simply club himher to death with a baseball bat  wildlifehumans are all gods living creatures and should be treated equally',
#  ' whilst some peoples instinct is to save wildlife other peoples is to reach for a baseball bat and beat the life out of it  with that standard reaction maybe it suggests the mind needs rewiring',
#  '  normally i agree with you but the risk with rabies the likelyhood is so so small but the price so so high  also last weekend i watched the president of the wildlife rescue org i m in manhandle an aggressive bat without gloves and she has a clotting disorder  ppl r stupid',
#  'whats the best way to get bats out of your house or barn dont kill them find out at      animals environment ',
#  ' you a  fan  maybe why do you carry a baseball bat in your home for smashing the brains out of stricken wildlife  kaaaaay    ',
#  'if that british lawyer who beat the fox to death with a baseball bat while wearing his wifes kimono sees the kylie minogue tourism ad he might come to australia and start beating our wildlife to death in ladys pyjamas and that is what we in the business would call a yarn',
#  '    no your not weird animals are only dumb because they cant talk certain species are very intelligent crows and ravens have been shown to be especially so others have learned to use tools so all lawyers beware or the wildlife might bat you',
#  ' yes  he chose to take a baseball bat and beat an animal to death if it was a dog or cat would you feel differently he could have called wildlife rescues for help  he chose to deliberately take the life of a defenceless animal ',
#  '      the wildlife and countryside act 1981 states that even though foxes are not protected by lawsome methods of killing them are prohibited  killing a fox with a baseball bat is an act of cruelty that caused unnecessary suffering  investigate please',
#  'today in the uk  bragging on twitter about killing a fox with a baseball bat  having a dead fox smashed against their vehicle window welcome to the uk where the wildlife protection act and the hunting with dogs act stands for fuck all',
#  '  firstly why is he using netting around a pen not only a fox but hedgehogs and other wildlife could get caught in it secondly why didnt he call the rspca or a local rescue the fox may have survived there was certainly no need to bash it with a baseball bat',
#  'labour needs a leader who is prepared to beat wildlife to death with a baseball bat',
#  ' we recently moved to a van in the woods we feed all the wild life incl the foxes amp make sure there s always fresh drinking water the owners have 2 geese left where originally there were 10 the foxes got some of them yet no one has ever been out stalking the site with a bat     ',
#  'plenty of beer football and pringles but i ve made it through boxing day without putting on a kimono and beating any wildlife to death with a baseball bat',
#  '   that s your fault for not housing your animals securely you should absolutely not be keeping chickens if it becomes your excuse to brutally kill scared trapped and hungry wildlife you should also be charged for keeping a baseball bat to use as a weapon',
#  ' the rspca in central london specifically are armed only with baseball bats they roam in packs battering wildlife to death nice for them to be saved a trip',
#  '   what to do when a bat gets in the home the bat valve is the most effective tool once exclusion is complete',
#  ' owen jones would write an article condemning cruelty to wildlife whilst handing him the bat',
#  '  foxes are protected under the wildlife and countryside act 1981 the wild mammals protection act 1996 the pesticides act 1998 the animal welfare act 2006 and the hunting act 2004 they are not vermin and it is both cruel and unnecessary to beat a fox to death with a bat',
#  ' no you call your nearest wildlife centre or the rspca not beat the poor animal to death with a baseball bat then gloat about it all over twitter shame on you',
#  '    there are wildlife out there with baseball bats sheesh',
#  ' i know someone from a certain wildlife trust who once knocked the head off a peacock with a baseball bat because it was destroying habit in his reserve',
#  '  he could have called the rspca or a wildlife rescue group if local he is a barrister supposed to be resourceful not without contacts its not nature for an human to beat a fox to death with a bat while it is helpless',
#  '  beating a fox to death with a baseball bat is both cruel and completely unnecessary in a country that is full of wildlife rescue organisations who will literally come to your house to catch illinjuredorphaned animals and humane pest control who will remove unwanted animals',
#  'so as well as admitting to the wildlife crime offence here our friendly legal expert is admitting to possessing an offensive weapon  possessing a baseball bat for playing baseball is fine possessing one to use as a weapon is not  ',
#  'if you find a fox tangled up in something in your garden   do not kill it with a baseball bat like    call the rspca or your local wildlife protection society tiggywinkles etc  the humane approach',
#  'fuck offf it was trapped in netting just call a wildlife centre to take it and take the chickens somewhere not bash its head in with a baseball bat',
#  ' no bat was required   i suggest you get yourself an animal control pole and a trap each  2030 on amazon to prevent further harm to wildlife or chickens  your tweet didn t cause me distress  killing an animal caused it distress',
#  '  it is just not normal is itanyone would try to release the fox or call a wildlife centre or rspca i dont know anyone that would think oh ill just bludgeon it to death with a baseball batseriously unhinged needs help i think',
#  '  yeah the rspca are well known for carrying baseball bats to dispatch dying wildlife',
#  'hey bat and wildlife twitter heres a seasonal bat crew job opportunity in or wa id and norcal remote fieldwork to deploy acoustic detectors for north american bat monitoring network         ',
#  '  never trust a man with a baseball bat who likes boasting about killing wildlife',
#  ' even if this fox attcked your chicken unsure we can  allow you to be all cocky about beating it up with a baseball bat      ',
#  '   it seems that running around outside in a kimono waving a baseball bat about at the wildlife is not an unusual thing for him to do or tweet about  ',
#  ' i cant follow someone who whacks wildlife with a baseball bat  whatever the merits of their other arguments clear link with violence against people   unfollowed',
#  ' disagree  a we dont eat foxes b killing with a baseball bat isnt humane c foxes arent bred for consumption but are wild and free you are entitled to your opinion but please dont call meat eaters hypocrites for caring about wildlife',
#  '  what planet are you on domestic cats are more of a problem for wildlife foxes are mostly shy scared dogscats only predate chickens if the owners havent made them secure i have kept chickens have you bludgeoning a fox trapped in netting with a baseball bat is not humane',
#  ' smashing an animals head in with a bat isnt something you would do to avoid unnecessary suffering normal sane people just call a wildlife rescue',
#  '    yes its all about money jobs and sport and at the wildlifes expense we were talking about  clubbing a fox to death with a baseball bat not a jolly afternoon out',
#  ' did that help you feel like a man was the animal attacking you or any childrenhell even chickens no you just did it for sport im not a big wildlife advocate but here in the us we shoot or trap them its more humane than a baseball bat clubbing their brains out asshole',
#  'i have sometimes needed to dispatch wildlife left horribly injured by carsother mishaps its always left me distraught i wouldnt tweet about it oh and unlike jo maugham as a professional biologist i am trained in home office approved humane methods doesnt include bats',
#  '  care to point out where the leaving an animal to suffer part is in call the rspcaa vetwildlife rescue approach to a injured animal   ive encountered rabbits with mixi ive never donned a kimono grabbed a baseball bat bludgeoned it amp then tweeted about it',
#  '    not endangered but foxes have declined by 40 nationally all wildlife is classed as protected under the animal welfare act 2006 s4 relating to causing unnecessary suffering to an animal whilst temporarily caught in netting and then he bludgeoned it death with a baseball bat',
#  ' apparently it got caught in the fence surrounding his chickens so he beat it to death with a bat instead of calling a vet or a wildlife charity',
#  'dont kill bats but you can do things to keep them out of your house and yard learn more     animals    ',
#  'already this morning ive managed not to beat any wildlife to death with a bat obviously im doing boxing day wrong  ',
#  '  our wildlife is literally dying bats falling dead from trees cockatoos dropping dead from the sky koalas burning to death in massive bushfires we dont know how many species have been lost forever in last few months australia is a front row seat at the anthropocene',
#  ' i think it depends on the english person clearly jo takes the grab your batshovelgun weirdo approach and id take the call the rspcaa vetwildlife rescue approach id hope most people would be in the latter group im very shocked that he decided to do that amp tweet that',
#  ' great before i read your tweet  apart from the immoral and illegal fox killing you also have wildlife trapping netting  so if it was a hedgehog or deer trapped would you have taken a baseball bat to them as well  your mistake and the fox paid with his life',
#  ' quite i have to be very careful with how i control vermin we couldn t walk around my stables with a baseball bat bashing wildlife the police would be knocking',
#  'some silverhaired bats migrate south for winter but this one was found trying to escape the cold in a barn hes now in care at twc receiving worms to eat once he gains some weight and learns to eat on his own hell hibernate at twc until he can be released in spring  ',
#  ' why didnt you call a wildlife rescue to come and release the fox  it does sound like you did rather enjoy taking a baseball bat to it',
#  ' the legislation applying to the protection of wildlife applies nationally  london is not excluded stop deflecting it deserves to be investigated do not dispose of the dead animal do not dispose of the baseball bat keep the  netting  as it was',
#  ' most vets will help wildlife a vet could have sedated and released if not injured euthanised humanely if needed christ i hope your neighbours pets dont wander near your netting you seem far too eager to grab a bat and report nonchalantly to twitter dont harmeat animals',
#  'anyone who brags about beating a fox to death with a baseball bat needs counselling for anger management amp extreme violence i hope the rspca take up a prosecution for cruelty to wildlife against well known qc     ',
#  ' the image it created sickened me  netting is a nightmare for all wildlife the poor creature must ve been terrified for god knows how long trapped in it amp he comes along with a baseball batand then brags about it on twitter  vile',
#  'this    fox gets caught in a safety netdecides the humane thing to do is club it to death with a bat   poor     ',
#  'a pigeon who has lost one foot is sitting on my back door should i a carry on trying to tame it by feeding it peanuts like i ve been doing all week in the hope of getting near enough to catch it and take it to a wildlife rescue centre b club it to death with a baseball bat',
#  ' if this is true  then shame on you you should have contacted the rspca or a wildlife rescue organisation                                  if you ever get stuck in a net watch out for the chap with the baseball bat',
#  ' odd tweet for a supposedly welleducated presumably civilised member of the legal profession cruel or humane  where did you get the baseball bative handled  foxes in a wildlife centreyou need gloves not baseball bats',
#  ' youve done what    that is against the law yet another case where some scum think they can act with impunity as the law select who gets prosecuted perhaps wildlife needs protection from you by someone bigger and stronger with his own baseball bat ',
#  '    well id have to take a view i suppose but my first thought wouldnt be to use a baseball bat but probably to call a local wildlife centre or a vet  are  really that bad can they comment',
#  'the guy who has been trying to thwart brexit at every given opportunity batters foxes to death with a baseball bat and then takes to twitter to brag about it the rspca dont tend to kill wildlife but if they did have to at least they may have done it humanely fucking savage',
#  'hot weather can be stressful for our wildlife leave out water for animals   but if you see distressed disorientated or unresponsive wildlife contact a rehab organisation vet or shelter info   remember if you see a bat you cant touch this     ',
#  'bats in the attic find out the best way to get rid of them at          ',
#  'cont for  psychic reading client there is a climate domino effect thats hurting all wildlife bats are dropping out of the trees dying because of the heatwaves and needing to stay hydrated if you can put out a water bucket further towards the street it might help',
#  'remember to think about our native wildlife during days of extreme heat like today leave out shallow dishes of water with a rock or stick in it for perching and call  if you have concerns about heat effected wildlife including bats 03 8400 7300 photo reg ryan  ',
#  ' its really alarming rod  a heap of volunteers from wildlife rescue were in the adel parkland yesty trying to help one report unverified says around 1500 infant bats fell out of the trees dead they are worried the increased heat today its awful',
#  'in indonesia the sulawesi is a biodiversity haven like very few other places on the planet it is home to many rare species such as the maleo megapode bird fruit bats and sea turtles             ',
#  'i agree  decision to cancel the wind project was not motivated by a desire to protect wildlife but wind turbines are not an imagined threat to bats amp birds also the bat species in the photo is not found anywhere near ontario  ',
#  'bat experts themselves are rejecting the cancellation of this  project because it contradicts the environmental review  lets protect  from real threats not the imagined ones that only serve the premiers agenda   ',
#  ' wildlife found  leigh wall rue and a mill lodge home to marginal plants and aquatic invertebrates these are known to further attract bats to the heritage site     ',
#  'the oh rescued this little  from the cat  fairly sure its a common  pipistrellus pipistrellus fascinating little creature amp pleased to report since putting out on a heap of pallets it has flown away       ',
#  ' thanks for sharing the article  i struggle to understand what is really going on with the nation rise cancellation i understand that there are going to be impacts on bird bat and other wildlife but it comes down to managing the impact to achieve a benefit',
#  'scientists with cdn wildlife service said in 2016 that bat kills by wind turbines was unsustainable that was 2013 data b4 huge k2wind henvey inlet amherst is and others started up    ',
#  ' once the  and  finished clearing under victoria bridge today  stepped in to take the plastic out of the inaccessible corner a passing cygnet  and a local bat not pictured  seemed to approve        ',
#  'have you heard of the woodland wildlife toolkit this is an online toolkit which provides advice amp guidance on managing woodlands for   in particular rare and declining species that are dependent on woodland habitats like a few  species    ',
#  'does it matter that cdn wildlife service scientists say current bat kills from wind turbines are unsustainable and that  doesnt need pwr from nation rise     ',
# ...
#  'great to meet  and listen to her thoughtprovoking talk on countryside access class and ethnicity   and we both have features in latest bbc wildlife mag mine about greater horseshoe bats    ',
#  'wonder what the long term effects will be to the wildlife birds bats etc or that not a concern',
#  'croton point parkthe other one pretended to be a bat and this one thinks he is a woodpecker     ',
#  'shadow dwellers                 ',
#  '  the truth is out massive cocaine overdoses decimate bat population fish amp wildlife blame white nose syndrome government coverup',
#  'croton point park an awesome place to be meet the cute little goldencrowned kinglet hanging upside down pretending to be a bat     ',
#  ' the husbandry skills of wildlife rehabilitators can help recover our north american bat populations with whitenose syndrome  nps biologist at ',
#  'so in one day amble way weve seen wild red squirrel deer bats seal shag heron eider moorhen swans mallards jackdaws pheasants coal tits blue tits magpies and terns apologies wildlife expert  friends my identification skills are a bit basic amazed at the variety',
#  'ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent  sign the petition   via ',
#  'ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent  sign the petition   via ',
#  'bats in the attic find out the best way to get rid of them at          ',
#  'ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent  sign the petition   via ',
#  'ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent  sign the petition   via ',
#  ' ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent   jetzt unterschreiben   via ',
#  'ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent  sign the petition   via ',
#  
#  'while you re preparing for halloween take a moment to appreciate  s notsospooky bats bats play a very important role in our ecosystem to protect these unique animals donate to our florida bat fund here        ',
#  'we had a bat in the studio today this is betsy from centre wildlife care   ',
#  'its international  week and one species of bat the indiana bat is featured in a new report showing the disastrous impacts of poisonous pesticides on imperiled wildlife     ',
#  'happy halloween to all the misunderstood  out there many people tell me that this wrinklefaced bat centurio senex is ugly but all i see is a gorgeous masterpiece of evolution the wrinkles may help fruit juices flow to its mouth when feeding    ',
#  'happy    remember bats arent scary and could really use the help of volunteers scientists and  lovers    ',
#  'happy halloween as you are waiting for trickortreaters to arrive take a few moments and learn more about bats and how you can help conserve these important animals by visiting      ',
#  'happy halloween its the last day to enter this spooktacularhalloween contest   hinterland whos who bat contest by watching the video and answering three simple questions about bats you could win a bat detector from wildlife acoustics    ',
#  'from bats to spiders certain wildlife conjures up a spooky image at  weve lined up some of the most common ones and the myths behind it read more here             photo guy edwardes2020vision  ',
#  'the 2019   highlights a black jaguar tarantula snowy owl vampire bat gray wolf and octopus learn interesting facts about these     via ',
#  'nothing could be scarier than seeing one of these   coming your way   if you re a mosquito or moth for the rest of us bats are vital to a healthy environment happy        ',
#  'were batty about pastette  this halloween     bats are a vital part of our native wildlife read how the dedicated volunteers in the isle of wight bat hospital who work with the  use our pastettes to feed baby bats in their care      ',
#  'spiders bats  ghost cats   it s the latest episode of amazing wildlife    ',
#  'ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent  sign the petition   via ',
#  'ashford borough council planning committee protect an ancient woodland and it s wildlife  barn owls badgers newts bats etc tpo oak trees from dubious developers in tenterden kent  sign the petition   via ',
#  'happy halloween from the wildlifetek team dont forget we turn into pumpkins at midnight thats when applications closeapply here        ',
#  'happy  everyone    please think about pets and wildlife including birds and bats if youre planning a bonfire or fireworks  thank you    ',
#  'wildlife groups are using halloween to remind people bats aren t as scary as the holiday has made them out to be  ',
#  'if bats are prevented from entering or exiting a roost without a licence or if bats are killed by being entombed this would be unlawful and could be a criminal offence   ',
#  'a fortunately timed restroom visit enabled a street vendor to abandon four elongated tortoises she planned to sell at the roadside in  she spotted uniforms and fled the scene after an   hotline tipoff     ',
#  'a fortunately timed restroom visit enabled a street vendor to abandon four elongated tortoises she planned to sell at the roadside in  she spotted uniforms and fled the scene after an   hotline tipoff     ',
#  ...]

# %% [markdown]
# ### Lemmatize words

# %%
#lemmatize words
import spacy
load_model = spacy.load('en_core_web_sm', disable = ['parser','ner'])
def lemmatize_tweet(tweet):
    doc = load_model(tweet)
    temp = " ".join([token.lemma_ for token in doc])
    return temp
lem_results = [lemmatize_tweet(tweet) for tweet in results]
lem_results

# %% [markdown]
# ### Filter out non-English words

# %%
#get rid of non-english words
import nltk
nltk.download('words')
words = set(nltk.corpus.words.words())
clean_tweet = []
for tweet in lem_results:
    clean_tweet.append(" ".join(w for w in nltk.wordpunct_tokenize(tweet) if w in words and w.isalpha()))
df['clean_tweet'] = clean_tweet

# %% [markdown]
# ### Scattertext

# %%
#create scattertext html of pre and post covid terms
import scattertext as st

df['metadata'] = df.created_at.map(str) + " | " + df.clean_tweet

nlp = spacy.load('en_core_web_sm')
nlp.Defaults.stop_words |= {"bat","wildlife"}
corpus = st.CorpusFromPandas(df, category_col='covid', text_col='clean_tweet', nlp=nlp).build()

html = st.produce_scattertext_explorer(corpus,
                                       category='pre',
                                       category_name='Pre-Covid',
                                       not_category_name='Post-Covid',
                                       width_in_pixels=1000,
                                       metadata = corpus.get_df()['metadata'])
open("pre_post_covid.html", 'wb').write(html.encode('utf-8'))

# %% [markdown]
# ### Some additional EDA adjustments

# %%
#get rid of some tweets that have little meaning, get rid of tweets about baseball
df = df[df.clean_tweet != 'read this about bat'] 
df = df[df.clean_tweet != 'what be bat']
df = df[df.clean_tweet != 'bat']
df = df[df.clean_tweet != 'the bat']
df = df[df.clean_tweet.str.contains("baseball bat")==False]
df.reset_index(drop = True, inplace=True)

# %% [markdown]
# ### Create wordclouds for before and after 2020

# %%
from wordcloud import WordCloud, STOPWORDS
from matplotlib import pyplot as plt

stopwords = ['bat','wildlife', 's'] + list(STOPWORDS)
pre_tweets = " ".join(tweet for tweet in df.clean_tweet[df.covid=='pre'])
pre_wordcloud = WordCloud(width = 3000,
                      height = 2000,
                      background_color = 'black',
                      stopwords = stopwords).generate(pre_tweets)
fig = plt.figure(figsize = (40, 30),
                 facecolor = 'k',
                 edgecolor = 'k')
plt.imshow(pre_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
plt.tight_layout()

# %%
post_tweets = " ".join(tweet for tweet in df.clean_tweet[df.covid=='post'])
post_wordcloud = WordCloud(width = 3000,
                      height = 2000,
                      background_color = 'black',
                      stopwords = stopwords).generate(post_tweets)
fig = plt.figure(figsize = (40, 30),
                 facecolor = 'k',
                 edgecolor = 'k')
plt.imshow(post_wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
plt.tight_layout()

# %% [markdown]
# ### Create document-term matrix using CountVectorizer

# %% [markdown]
# Note that I tried both TfidfVectorizer and CountVectorizer and found topics to be more coherent using CountVectorizer. This feels like an acceptable choice given that tweets are relatively short.

# %%
#create document term matrix
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.feature_extraction import text

#specify stop words to remove
my_stop_words = text.ENGLISH_STOP_WORDS.union(["aa","bat","wildlife","just","like",
                                               "great","make","work","new","know","s"]) 
cv = CountVectorizer(strip_accents = "ascii",
                          stop_words = my_stop_words)
X = cv.fit_transform(df.clean_tweet).toarray()
df_cv = pd.DataFrame(X, index = df.clean_tweet,columns = cv.get_feature_names())

# %%
df_cv.shape

# %%
#look at most common words to get a gut check on if things are making sense
df_cv.sum().sort_values(ascending = False).head(20)

# %% [markdown]
# ### Perform topic modeling using non-negative matrix factorization

# %%
#topic modeling
from sklearn.decomposition import NMF
nmf = NMF(n_components=3, init = "nndsvda", max_iter=500)
doc_topic = nmf.fit_transform(df_cv)

# %%
nmf.components_.shape

# %%
def get_top_terms(topic, n_terms, nmf=nmf, terms=df_cv.columns):
    # get the topic components (i.e., term weights)
    components = nmf.components_[topic, :]

    # get term indices, sorted (descending) by topic weights
    top_term_indices = components.argsort()[-n_terms:]
    
    # use the `terms` array to get the actual top terms
    top_terms = np.array(terms)[top_term_indices]
    
    return top_terms.tolist()

# %%
#show the top 10 terms in each topic
topic_terms_df = pd.DataFrame()
for i in range(0,3):
    topic_terms = pd.Series(get_top_terms(i,10), name = i)
    topic_terms_df = pd.concat([topic_terms_df, topic_terms], axis = 1)
    print(f'Topic {i}:')
    print(get_top_terms(i, 10))
    print("\n")
topic_terms_df.rename(mapper = {0:'Wind',1:'Disease',2:'Habitat'}, axis = 1, inplace = True)

# %%
topic_terms_df

# %%
#name topics and create a dataframe of topic focus for each tweet
topic_names = ["wind","disease","habitat"]
doc_topic_df = pd.DataFrame(doc_topic.round(5), index = df.index, columns = topic_names)

# %%
#label each document with its primary topic
doc_topic_df['primary_topic'] = doc_topic_df.idxmax(axis=1)

# %%
#add the primary topic of each document to the original dataframe
df = pd.merge(df, doc_topic_df.primary_topic, 
                  left_index=True, right_index=True)
df.head()

# %%
#look at overall frequency of different topics
import seaborn as sns

fig, ax = plt.subplots()
ax.hist(df.primary_topic)
fig.suptitle('Topic Frequency')
fig.tight_layout();

# %% [markdown]
# ### Sentiment analysis using Vader

# %%
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()
df['score'] = df.clean_tweet.map(analyzer.polarity_scores).map(lambda x: x.get('compound'))

# %%
#print the most positive tweet
df.clean_tweet.iloc[df.score.idxmax()]

# %%
#print the most negative tweet
df.clean_tweet.iloc[df.score.idxmin()]

# %%
#print the overall sentiment score
df.score.mean()

# %%
#assign positive or negative overall score to each tweet and then calculate percentage of positive tweets
df['sent'] = df.score.apply(lambda x: 'pos' if x>=0 else 'neg')
print("Percentage of negative tweets about bats pre-Covid:")
print(f"{(((df[df.covid=='pre'].sent[df.sent=='neg'].count())/len(df[df.covid=='pre']))*100).round(2)}%\n")
print(f"Percentage of negative tweets about bats post-Covid:")
print(f"{(((df[df.covid=='post'].sent[df.sent=='neg'].count())/len(df[df.covid=='post']))*100).round(2)}%\n")

# %% [markdown]
# ### Vizualize change in topics over time

# %%
df['month_year'] = df['created_at'].dt.to_period('M')

# %%
topic_count_df = df.groupby(['month_year','primary_topic'])['primary_topic'].count().to_frame(name='topic_count').reset_index()

# %%
topic_count_df.head()

# %%
plt.rcParams.update({'font.size': 14})
fig, ax = plt.subplots()
fig.set_size_inches(11, 8)
plt.plot_date(topic_count_df['month_year'][topic_count_df.primary_topic == "habitat"], 
              topic_count_df['topic_count'][topic_count_df.primary_topic == "habitat"], 
             xdate=True,
             ydate=False,
             linestyle = 'dotted')
plt.plot_date(topic_count_df['month_year'][topic_count_df.primary_topic == "wind"], 
              topic_count_df['topic_count'][topic_count_df.primary_topic == "wind"], 
             xdate=True,
             ydate=False,
             linestyle = 'dotted')
plt.plot_date(topic_count_df['month_year'][topic_count_df.primary_topic == "disease"], 
              topic_count_df['topic_count'][topic_count_df.primary_topic == "disease"], 
             xdate=True,
             ydate=False,
             linestyle = 'dotted')
ax.legend(labels=['Habitat','Wind','Disease'])
ax.set_ylabel('Count of Tweets')
fig.suptitle('Topics Over Time')
ax.tick_params(labelrotation=45)
plt.tight_layout()
fig.savefig('topics_over_time.png', dpi=100)
plt.show()
